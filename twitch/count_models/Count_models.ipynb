# %% [markdown]
# # Count models
#
# Counting is easy, right? Not so fast, bub...
#
# Plan: talk about counting
#
# * car crashes (TDOT data)
# * births (U.S. Census data, via Wonder)
# * coughs (proprietary Hyfe data)

# %% [markdown]
# ## Imports and settings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as st

# %%
sns.set_theme()
plt.rcParams['figure.figsize'] = [12,8]

# %% [markdown]
# ## Monthly car crashes

# %%
crashes = pd.read_csv("TDOT.csv")
crashes
# Out:
#           County  Year  January  February  March  April  May  June  July  \
# 0       Anderson  2010      138       113    169    169  155   152   165
# 1        Bedford  2010       71        72     77     70   87    99    90
# 2         Benton  2010       21        23     27     32   34    29    16
# 3        Bledsoe  2010        5         1      3      3    5     1     7
# 4         Blount  2010      126       159    171    145  153   139   201
# ...          ...   ...      ...       ...    ...    ...  ...   ...   ...
# 1040       Wayne  2020       23        15     19     27   18    22    20
# 1041     Weakley  2020       39        35     40     19   28    43    37
# 1042       White  2020       30        31     33     21   50    32    36
# 1043  Williamson  2020      394       424    270    170  226   304   312
# 1044      Wilson  2020      282       268    239    143  267   258   285
#
#       August  September  October  November  December
# ...

# %% [markdown]
# ### Meigs county: Poisson-distributed crashes

# %%
meigs = crashes[crashes["County"]=="Meigs"]
meigs = meigs.drop("County",1)
meigs
# Out:
#       Year  January  February  March  April  May  June  July  August  \
# 60    2010       11         8     10     14   18    12    17      15
# 155   2011       13        14     15      8   13    14     8      14
# 250   2012       12         5     14     11   14    12    16      15
# 345   2013       10        11     15     19   17     6    10      14
# 440   2014       16        16     17     11   16     8     9      13
# 535   2015       10        16     16     14   20    18    16      14
# 630   2016       18        15     17     18   14    14    21      16
# 725   2017       13        12     15     15   12    10    14       9
# 820   2018       14        18     13     10   13    16    12      11
# 915   2019       12         9      6      9   14    20    10      14
# 1010  2020       13         9     13     12   13    16    10       9
#
#       September  October  November  December
# 60           16       11        18        14
# 155          13       13        14         8
# ...

# %%
meigs = meigs.melt( id_vars="Year", var_name="Month", value_name="Crashes" )
meigs
# Out:
#      Year     Month  Crashes
# 0    2010   January       11
# 1    2011   January       13
# 2    2012   January       12
# 3    2013   January       10
# 4    2014   January       16
# ..    ...       ...      ...
# 127  2016  December       16
# 128  2017  December       18
# 129  2018  December        9
# 130  2019  December       11
# 131  2020  December       17
#
# [132 rows x 3 columns]

# %%
meigs.agg( Mean = ("Crashes","mean"), Variance = ("Crashes","var") )
# Out:
#             Crashes
# Mean      13.712121
# Variance  15.198936

# %%
meigs_hist = sns.histplot( data=meigs, x="Crashes", discrete=True)

# %%
meigs.shape
# Out:
# (132, 3)

# %%
r = pd.DataFrame({"Sample":st.poisson.rvs(13.7,size=132)})
sns.histplot(data=r, x="Sample", discrete=True)
plt.xlim(meigs_hist.get_xlim())
# Out:
# (2.95, 37.05)

# %% [markdown]
# ### The Poisson distribution
#
# This is a _count variable_, a random variable whose only possible values are _nonnegative integers_. In fact, this is a _Poisson random variable_ with parameter $\mu$:
# $$P(X=k) ~ = ~ e^{-\mu} \, \frac{ \mu^{k} }{ k! } \ , \quad \text{for} \quad k \in \mathbb{N} . $$
#
# Both the average and the variance of this random variable equal $\mu$.

# %% [markdown]
# ### Knox county: Overdispersed crashes

# %%
knox = crashes[crashes["County"]=="Knox"]
knox = knox.drop("County",1)
knox
# Out:
#      Year  January  February  March  April   May  June  July  August  \
# 46   2010      894       858   1027   1110  1058   974   906    1005
# 141  2011      804       805   1059   1026   993  1069  1028    1104
# 236  2012      984      1048   1161   1116  1087   933   978    1068
# 331  2013     1001       822   1042   1075  1100   968   977    1115
# 426  2014      928       846    939   1083  1041   891   982    1061
# 521  2015      992       797   1055   1146  1103   977  1083    1185
# 616  2016      981      1015   1154   1176  1137  1111  1175    1291
# 711  2017      984      1030   1200   1273  1195  1188  1067    1261
# 806  2018     1052      1077   1177   1257  1233  1162  1092    1277
# 901  2019     1104      1079   1252   1294  1177  1087  1092    1221
# 996  2020     1173      1152    879    464   724   867  1008    1139
#
#      September  October  November  December
# 46        1177     1156      1149       940
# 141       1070     1188      1214      1136
# ...

# %%
knox = knox.melt( id_vars="Year", var_name="Month", value_name="Crashes" )
knox.agg( Mean = ("Crashes","mean"), Variance = ("Crashes","var") )
# Out:
#                Crashes
# Mean       1095.613636
# Variance  22377.185461

# %%
knox_hist = sns.histplot( data=knox, x="Crashes")

# %%
r = pd.DataFrame({"Sample":st.poisson.rvs(1095.6,size=132)})
sns.histplot(data=r, x="Sample")
plt.xlim(knox_hist.get_xlim())
# Out:
# (415.35, 1485.65)

# %% [markdown]
# The monthly crashes in Knox county do _NOT_ follow a Poisson distribution!
